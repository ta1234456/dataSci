# %% [markdown]
# # Project

# %% [markdown]
# ### Members
#
# - xxx
# - xxx
# - xxx

# %% [markdown]
# ### Data Source
#     - xx

# %% [markdown]
# ### Impoer All Libraries

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('laptop_prices.csv')
df
# Out:
#      Company                              Product            TypeName  Inches  \
# 0      Apple                          MacBook Pro           Ultrabook    13.3
# 1      Apple                          Macbook Air           Ultrabook    13.3
# 2         HP                               250 G6            Notebook    15.6
# 3      Apple                          MacBook Pro           Ultrabook    15.4
# 4      Apple                          MacBook Pro           Ultrabook    13.3
# ...      ...                                  ...                 ...     ...
# 1270  Lenovo                       Yoga 500-14ISK  2 in 1 Convertible    14.0
# 1271  Lenovo                       Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1272  Lenovo                   IdeaPad 100S-14IBR            Notebook    14.0
# 1273      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook    15.6
# 1274    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook    15.6
#
# ...

# %%
df.groupby('Company').size().sort_values()
# Out:
# Company
# Huawei         2
# LG             3
# Chuwi          3
# Google         3
# Fujitsu        3
# Vero           4
# Xiaomi         4
# Microsoft      6
# Mediacom       7
# Razer          7
# Samsung        9
# Apple         21
# Toshiba       48
# MSI           54
# Acer         101
# Asus         152
# HP           268
# Lenovo       289
# Dell         291
# dtype: int64

# %%
df['OS'].unique()
# Out:
# array(['macOS', 'No OS', 'Windows 10', 'Mac OS X', 'Linux', 'Android',
#        'Windows 10 S', 'Chrome OS', 'Windows 7'], dtype=object)

# %%
df.loc[df['SecondaryStorage'] != 0,:]
# Out:
#      Company             Product   TypeName  Inches  Ram          OS  Weight  \
# 21    Lenovo  Legion Y520-15IKBN     Gaming    15.6    8  Windows 10    2.50
# 28      Dell       Latitude 5590  Ultrabook    15.6    8  Windows 10    1.88
# 37      Dell       Inspiron 5770   Notebook    17.3    8  Windows 10    2.80
# 41      Dell       Inspiron 7577     Gaming    15.6   16  Windows 10    2.65
# 47      Asus           Rog Strix     Gaming    17.3    8  Windows 10    3.20
# ...      ...                 ...        ...     ...  ...         ...     ...
# 1238     MSI            GL62 6QF     Gaming    15.6    8  Windows 10    2.30
# 1245    Asus  Rog GL553VE-FY052T     Gaming    15.6   16  Windows 10    2.50
# 1247    Asus         Rog GL502VS     Gaming    15.6   16  Windows 10    2.34
# 1256    Asus   Rog G752VT-GC073T     Gaming    17.3   16  Windows 10    4.00
# 1259     MSI         GE62 Apache     Gaming    15.6    8  Windows 10    2.40
#
# ...

# %%
df_2 = pd.read_csv("country_comparison_large_dataset.csv")
df_2
# Out:
#        Country  Year  GDP (in Trillions USD)  GDP per Capita (in USD)  \
# 0          USA  2000                   20.87                  65455.0
# 1       Russia  2000                    1.64                  10923.0
# 2       Canada  2000                    1.65                  47932.0
# 3        China  2000                   13.64                  10060.0
# 4        India  2000                    2.98                   2102.1
# ..         ...   ...                     ...                      ...
# 139     Russia  2023                    1.64                  10978.0
# 140     Canada  2023                    1.73                  44804.0
# 141      China  2023                   13.72                   9870.0
# 142      India  2023                    2.79                   2070.6
# 143  Australia  2023                    1.27                  51304.0
#
#      Inflation Rate (%)  Population (in Millions)  Population Growth Rate (%)  \
# ...

# %%
df_2['Year'].unique()
# Out:
# array([2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
#        2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021,
#        2022, 2023], dtype=int64)
